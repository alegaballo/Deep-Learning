# %%
import matplotlib.pyplot as plt
import numpy as np

x =  np.arange(0,50)

# %%
y1  = np.random.rand(50)
y2 = np.random.rand(50)
y3 = np.random.rand(50)

# %%
plt.figure(figsize=(18, 10))
plt.xticks(x)
plt.xlabel('Iteration')
plt.ylabel('Validation accuracy')
plt.title('Validation accuracies per different learning rates')
plt.grid()
plt.plot(x,y1, label=0)
plt.plot(x,y2, label='a2')
plt.plot(x,y3, label='a3')
plt.legend(title="mena")
plt.show()

# %%
x = []
x.append(1)
print(x[-1])
x.append(4)
print(x[-1])
# Out:
# 1
# 4

# %%
plt.plot([100,200,300], [50,60,55])
plt.show()
